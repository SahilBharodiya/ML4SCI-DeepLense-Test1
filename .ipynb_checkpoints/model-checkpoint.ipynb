# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import tensorflow as tf

# %%
train_X = np.load('train_X.npy')
train_y = np.load('train_y.npy')

test_X = np.load('test_X.npy')
test_y = np.load('test_y.npy')

# %%
train = list(zip(train_X, train_y))

random.shuffle(train)

train_X, train_y = zip(*train)

train_X = np.array(train_X)
train_y = np.array(train_y)

# %%
test = list(zip(test_X, test_y))

random.shuffle(test)

test_X, test_y = zip(*test)

test_X = np.array(test_X)
test_y = np.array(test_y)

# %%
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_X[i])
    plt.xlabel(train_y[i])
plt.show()

# %%
train_X.shape, train_y.shape, test_X.shape, test_y.shape
# Out:
# ((30000, 32, 32, 3), (30000,), (7500, 32, 32, 3), (7500,))

# %%
model = tf.keras.applications.ResNet152V2(include_top=False, weights='imagenet', input_shape=(32, 32, 3))

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# 2022-03-17 11:42:48.148979: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-17 11:42:48.154361: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-17 11:42:48.154619: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-17 11:42:48.155092: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-03-17 11:42:48.155550: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-17 11:42:48.155779: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-17 11:42:48.155888: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-17 11:42:48.535120: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-17 11:42:48.535269: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-17 11:42:48.535381: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-03-17 11:42:48.535480: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3368 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1050, pci bus id: 0000:01:00.0, compute capability: 6.1
# Model: "resnet152v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv1_pad (ZeroPadding2D)      (None, 38, 38, 3)    0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 16, 16, 64)   9472        ['conv1_pad[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 18, 18, 64)   0           ['conv1_conv[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 8, 8, 64)     0           ['pool1_pad[0][0]']
#
#  conv2_block1_preact_bn (BatchN  (None, 8, 8, 64)    256         ['pool1_pool[0][0]']
#  ormalization)
#
#  conv2_block1_preact_relu (Acti  (None, 8, 8, 64)    0           ['conv2_block1_preact_bn[0][0]']
#  vation)
#
#  conv2_block1_1_conv (Conv2D)   (None, 8, 8, 64)     4096        ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_1_bn (BatchNormal  (None, 8, 8, 64)    256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 8, 8, 64)    0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_pad (ZeroPaddin  (None, 10, 10, 64)  0           ['conv2_block1_1_relu[0][0]']
#  g2D)
#
#  conv2_block1_2_conv (Conv2D)   (None, 8, 8, 64)     36864       ['conv2_block1_2_pad[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 8, 8, 64)    256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 8, 8, 64)    0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 8, 8, 256)    16640       ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_3_conv (Conv2D)   (None, 8, 8, 256)    16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_out (Add)         (None, 8, 8, 256)    0           ['conv2_block1_0_conv[0][0]',
#                                                                   'conv2_block1_3_conv[0][0]']
#
#  conv2_block2_preact_bn (BatchN  (None, 8, 8, 256)   1024        ['conv2_block1_out[0][0]']
#  ormalization)
#
#  conv2_block2_preact_relu (Acti  (None, 8, 8, 256)   0           ['conv2_block2_preact_bn[0][0]']
#  vation)
#
#  conv2_block2_1_conv (Conv2D)   (None, 8, 8, 64)     16384       ['conv2_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block2_1_bn (BatchNormal  (None, 8, 8, 64)    256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 8, 8, 64)    0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_pad (ZeroPaddin  (None, 10, 10, 64)  0           ['conv2_block2_1_relu[0][0]']
#  g2D)
#
#  conv2_block2_2_conv (Conv2D)   (None, 8, 8, 64)     36864       ['conv2_block2_2_pad[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 8, 8, 64)    256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 8, 8, 64)    0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 8, 8, 256)    16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_out (Add)         (None, 8, 8, 256)    0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_conv[0][0]']
#
#  conv2_block3_preact_bn (BatchN  (None, 8, 8, 256)   1024        ['conv2_block2_out[0][0]']
#  ormalization)
#
#  conv2_block3_preact_relu (Acti  (None, 8, 8, 256)   0           ['conv2_block3_preact_bn[0][0]']
#  vation)
#
#  conv2_block3_1_conv (Conv2D)   (None, 8, 8, 64)     16384       ['conv2_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block3_1_bn (BatchNormal  (None, 8, 8, 64)    256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 8, 8, 64)    0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_pad (ZeroPaddin  (None, 10, 10, 64)  0           ['conv2_block3_1_relu[0][0]']
#  g2D)
#
#  conv2_block3_2_conv (Conv2D)   (None, 4, 4, 64)     36864       ['conv2_block3_2_pad[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 4, 4, 64)    256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 4, 4, 64)    0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  max_pooling2d (MaxPooling2D)   (None, 4, 4, 256)    0           ['conv2_block2_out[0][0]']
#
#  conv2_block3_3_conv (Conv2D)   (None, 4, 4, 256)    16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_out (Add)         (None, 4, 4, 256)    0           ['max_pooling2d[0][0]',
#                                                                   'conv2_block3_3_conv[0][0]']
#
#  conv3_block1_preact_bn (BatchN  (None, 4, 4, 256)   1024        ['conv2_block3_out[0][0]']
#  ormalization)
#
#  conv3_block1_preact_relu (Acti  (None, 4, 4, 256)   0           ['conv3_block1_preact_bn[0][0]']
#  vation)
#
#  conv3_block1_1_conv (Conv2D)   (None, 4, 4, 128)    32768       ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_1_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 4, 4, 128)   0           ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_pad (ZeroPaddin  (None, 6, 6, 128)   0           ['conv3_block1_1_relu[0][0]']
#  g2D)
#
#  conv3_block1_2_conv (Conv2D)   (None, 4, 4, 128)    147456      ['conv3_block1_2_pad[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 4, 4, 128)   0           ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 4, 4, 512)    131584      ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_3_conv (Conv2D)   (None, 4, 4, 512)    66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_out (Add)         (None, 4, 4, 512)    0           ['conv3_block1_0_conv[0][0]',
#                                                                   'conv3_block1_3_conv[0][0]']
#
#  conv3_block2_preact_bn (BatchN  (None, 4, 4, 512)   2048        ['conv3_block1_out[0][0]']
#  ormalization)
#
#  conv3_block2_preact_relu (Acti  (None, 4, 4, 512)   0           ['conv3_block2_preact_bn[0][0]']
#  vation)
#
#  conv3_block2_1_conv (Conv2D)   (None, 4, 4, 128)    65536       ['conv3_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block2_1_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 4, 4, 128)   0           ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_pad (ZeroPaddin  (None, 6, 6, 128)   0           ['conv3_block2_1_relu[0][0]']
#  g2D)
#
#  conv3_block2_2_conv (Conv2D)   (None, 4, 4, 128)    147456      ['conv3_block2_2_pad[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 4, 4, 128)   0           ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 4, 4, 512)    66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_out (Add)         (None, 4, 4, 512)    0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_conv[0][0]']
#
#  conv3_block3_preact_bn (BatchN  (None, 4, 4, 512)   2048        ['conv3_block2_out[0][0]']
#  ormalization)
#
#  conv3_block3_preact_relu (Acti  (None, 4, 4, 512)   0           ['conv3_block3_preact_bn[0][0]']
#  vation)
#
#  conv3_block3_1_conv (Conv2D)   (None, 4, 4, 128)    65536       ['conv3_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block3_1_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 4, 4, 128)   0           ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_pad (ZeroPaddin  (None, 6, 6, 128)   0           ['conv3_block3_1_relu[0][0]']
#  g2D)
#
#  conv3_block3_2_conv (Conv2D)   (None, 4, 4, 128)    147456      ['conv3_block3_2_pad[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 4, 4, 128)   0           ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 4, 4, 512)    66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_out (Add)         (None, 4, 4, 512)    0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_conv[0][0]']
#
#  conv3_block4_preact_bn (BatchN  (None, 4, 4, 512)   2048        ['conv3_block3_out[0][0]']
#  ormalization)
#
#  conv3_block4_preact_relu (Acti  (None, 4, 4, 512)   0           ['conv3_block4_preact_bn[0][0]']
#  vation)
#
#  conv3_block4_1_conv (Conv2D)   (None, 4, 4, 128)    65536       ['conv3_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block4_1_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 4, 4, 128)   0           ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_pad (ZeroPaddin  (None, 6, 6, 128)   0           ['conv3_block4_1_relu[0][0]']
#  g2D)
#
#  conv3_block4_2_conv (Conv2D)   (None, 4, 4, 128)    147456      ['conv3_block4_2_pad[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 4, 4, 128)   0           ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 4, 4, 512)    66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_out (Add)         (None, 4, 4, 512)    0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_conv[0][0]']
#
#  conv3_block5_preact_bn (BatchN  (None, 4, 4, 512)   2048        ['conv3_block4_out[0][0]']
#  ormalization)
#
#  conv3_block5_preact_relu (Acti  (None, 4, 4, 512)   0           ['conv3_block5_preact_bn[0][0]']
#  vation)
#
#  conv3_block5_1_conv (Conv2D)   (None, 4, 4, 128)    65536       ['conv3_block5_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block5_1_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 4, 4, 128)   0           ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_pad (ZeroPaddin  (None, 6, 6, 128)   0           ['conv3_block5_1_relu[0][0]']
#  g2D)
#
#  conv3_block5_2_conv (Conv2D)   (None, 4, 4, 128)    147456      ['conv3_block5_2_pad[0][0]']
#
#  conv3_block5_2_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv3_block5_2_conv[0][0]']
#  ization)
#
#  conv3_block5_2_relu (Activatio  (None, 4, 4, 128)   0           ['conv3_block5_2_bn[0][0]']
#  n)
#
#  conv3_block5_3_conv (Conv2D)   (None, 4, 4, 512)    66048       ['conv3_block5_2_relu[0][0]']
#
#  conv3_block5_out (Add)         (None, 4, 4, 512)    0           ['conv3_block4_out[0][0]',
#                                                                   'conv3_block5_3_conv[0][0]']
#
#  conv3_block6_preact_bn (BatchN  (None, 4, 4, 512)   2048        ['conv3_block5_out[0][0]']
#  ormalization)
#
#  conv3_block6_preact_relu (Acti  (None, 4, 4, 512)   0           ['conv3_block6_preact_bn[0][0]']
#  vation)
#
#  conv3_block6_1_conv (Conv2D)   (None, 4, 4, 128)    65536       ['conv3_block6_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block6_1_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 4, 4, 128)   0           ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_pad (ZeroPaddin  (None, 6, 6, 128)   0           ['conv3_block6_1_relu[0][0]']
#  g2D)
#
#  conv3_block6_2_conv (Conv2D)   (None, 4, 4, 128)    147456      ['conv3_block6_2_pad[0][0]']
#
#  conv3_block6_2_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv3_block6_2_conv[0][0]']
#  ization)
#
#  conv3_block6_2_relu (Activatio  (None, 4, 4, 128)   0           ['conv3_block6_2_bn[0][0]']
#  n)
#
#  conv3_block6_3_conv (Conv2D)   (None, 4, 4, 512)    66048       ['conv3_block6_2_relu[0][0]']
#
#  conv3_block6_out (Add)         (None, 4, 4, 512)    0           ['conv3_block5_out[0][0]',
#                                                                   'conv3_block6_3_conv[0][0]']
#
#  conv3_block7_preact_bn (BatchN  (None, 4, 4, 512)   2048        ['conv3_block6_out[0][0]']
#  ormalization)
#
#  conv3_block7_preact_relu (Acti  (None, 4, 4, 512)   0           ['conv3_block7_preact_bn[0][0]']
#  vation)
#
#  conv3_block7_1_conv (Conv2D)   (None, 4, 4, 128)    65536       ['conv3_block7_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block7_1_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 4, 4, 128)   0           ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_pad (ZeroPaddin  (None, 6, 6, 128)   0           ['conv3_block7_1_relu[0][0]']
#  g2D)
#
#  conv3_block7_2_conv (Conv2D)   (None, 4, 4, 128)    147456      ['conv3_block7_2_pad[0][0]']
#
#  conv3_block7_2_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv3_block7_2_conv[0][0]']
#  ization)
#
#  conv3_block7_2_relu (Activatio  (None, 4, 4, 128)   0           ['conv3_block7_2_bn[0][0]']
#  n)
#
#  conv3_block7_3_conv (Conv2D)   (None, 4, 4, 512)    66048       ['conv3_block7_2_relu[0][0]']
#
#  conv3_block7_out (Add)         (None, 4, 4, 512)    0           ['conv3_block6_out[0][0]',
#                                                                   'conv3_block7_3_conv[0][0]']
#
#  conv3_block8_preact_bn (BatchN  (None, 4, 4, 512)   2048        ['conv3_block7_out[0][0]']
#  ormalization)
#
#  conv3_block8_preact_relu (Acti  (None, 4, 4, 512)   0           ['conv3_block8_preact_bn[0][0]']
#  vation)
#
#  conv3_block8_1_conv (Conv2D)   (None, 4, 4, 128)    65536       ['conv3_block8_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block8_1_bn (BatchNormal  (None, 4, 4, 128)   512         ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 4, 4, 128)   0           ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_pad (ZeroPaddin  (None, 6, 6, 128)   0           ['conv3_block8_1_relu[0][0]']
#  g2D)
#
#  conv3_block8_2_conv (Conv2D)   (None, 2, 2, 128)    147456      ['conv3_block8_2_pad[0][0]']
#
#  conv3_block8_2_bn (BatchNormal  (None, 2, 2, 128)   512         ['conv3_block8_2_conv[0][0]']
#  ization)
#
#  conv3_block8_2_relu (Activatio  (None, 2, 2, 128)   0           ['conv3_block8_2_bn[0][0]']
#  n)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 2, 2, 512)   0           ['conv3_block7_out[0][0]']
#
#  conv3_block8_3_conv (Conv2D)   (None, 2, 2, 512)    66048       ['conv3_block8_2_relu[0][0]']
#
#  conv3_block8_out (Add)         (None, 2, 2, 512)    0           ['max_pooling2d_1[0][0]',
#                                                                   'conv3_block8_3_conv[0][0]']
#
#  conv4_block1_preact_bn (BatchN  (None, 2, 2, 512)   2048        ['conv3_block8_out[0][0]']
#  ormalization)
#
#  conv4_block1_preact_relu (Acti  (None, 2, 2, 512)   0           ['conv4_block1_preact_bn[0][0]']
#  vation)
#
#  conv4_block1_1_conv (Conv2D)   (None, 2, 2, 256)    131072      ['conv4_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block1_1_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_pad (ZeroPaddin  (None, 4, 4, 256)   0           ['conv4_block1_1_relu[0][0]']
#  g2D)
#
#  conv4_block1_2_conv (Conv2D)   (None, 2, 2, 256)    589824      ['conv4_block1_2_pad[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 2, 2, 1024)   525312      ['conv4_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block1_3_conv (Conv2D)   (None, 2, 2, 1024)   263168      ['conv4_block1_2_relu[0][0]']
#
#  conv4_block1_out (Add)         (None, 2, 2, 1024)   0           ['conv4_block1_0_conv[0][0]',
#                                                                   'conv4_block1_3_conv[0][0]']
#
#  conv4_block2_preact_bn (BatchN  (None, 2, 2, 1024)  4096        ['conv4_block1_out[0][0]']
#  ormalization)
#
#  conv4_block2_preact_relu (Acti  (None, 2, 2, 1024)  0           ['conv4_block2_preact_bn[0][0]']
#  vation)
#
#  conv4_block2_1_conv (Conv2D)   (None, 2, 2, 256)    262144      ['conv4_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block2_1_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_pad (ZeroPaddin  (None, 4, 4, 256)   0           ['conv4_block2_1_relu[0][0]']
#  g2D)
#
#  conv4_block2_2_conv (Conv2D)   (None, 2, 2, 256)    589824      ['conv4_block2_2_pad[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 2, 2, 1024)   263168      ['conv4_block2_2_relu[0][0]']
#
#  conv4_block2_out (Add)         (None, 2, 2, 1024)   0           ['conv4_block1_out[0][0]',
#                                                                   'conv4_block2_3_conv[0][0]']
#
#  conv4_block3_preact_bn (BatchN  (None, 2, 2, 1024)  4096        ['conv4_block2_out[0][0]']
#  ormalization)
#
#  conv4_block3_preact_relu (Acti  (None, 2, 2, 1024)  0           ['conv4_block3_preact_bn[0][0]']
#  vation)
#
#  conv4_block3_1_conv (Conv2D)   (None, 2, 2, 256)    262144      ['conv4_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block3_1_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_pad (ZeroPaddin  (None, 4, 4, 256)   0           ['conv4_block3_1_relu[0][0]']
#  g2D)
#
#  conv4_block3_2_conv (Conv2D)   (None, 2, 2, 256)    589824      ['conv4_block3_2_pad[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 2, 2, 256)   1024        ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 2, 2, 256)   0           ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 2, 2, 1024)   263168      ['conv4_block3_2_relu[0][0]']
#
#  conv4_block3_out (Add)         (None, 2, 2, 1024)   0           ['conv4_block2_out[0][0]',
#                                                                   'conv4_block3_3_conv[0][0]']
#
#  conv4_block4_preact_bn (BatchN  (None, 2, 2, 1024)  4096        ['conv4_block3_out[0][0]']
# ...
#  ivation)
#
#  conv4_block35_1_conv (Conv2D)  (None, 2, 2, 256)    262144      ['conv4_block35_preact_relu[0][0]
#                                                                  ']
#
#  conv4_block35_1_bn (BatchNorma  (None, 2, 2, 256)   1024        ['conv4_block35_1_conv[0][0]']
#  lization)
#
#  conv4_block35_1_relu (Activati  (None, 2, 2, 256)   0           ['conv4_block35_1_bn[0][0]']
#  on)
#
#  conv4_block35_2_pad (ZeroPaddi  (None, 4, 4, 256)   0           ['conv4_block35_1_relu[0][0]']
#  ng2D)
#
#  conv4_block35_2_conv (Conv2D)  (None, 2, 2, 256)    589824      ['conv4_block35_2_pad[0][0]']
#
#  conv4_block35_2_bn (BatchNorma  (None, 2, 2, 256)   1024        ['conv4_block35_2_conv[0][0]']
#  lization)
#
#  conv4_block35_2_relu (Activati  (None, 2, 2, 256)   0           ['conv4_block35_2_bn[0][0]']
#  on)
#
#  conv4_block35_3_conv (Conv2D)  (None, 2, 2, 1024)   263168      ['conv4_block35_2_relu[0][0]']
#
#  conv4_block35_out (Add)        (None, 2, 2, 1024)   0           ['conv4_block34_out[0][0]',
#                                                                   'conv4_block35_3_conv[0][0]']
#
#  conv4_block36_preact_bn (Batch  (None, 2, 2, 1024)  4096        ['conv4_block35_out[0][0]']
#  Normalization)
#
#  conv4_block36_preact_relu (Act  (None, 2, 2, 1024)  0           ['conv4_block36_preact_bn[0][0]']
#  ivation)
#
#  conv4_block36_1_conv (Conv2D)  (None, 2, 2, 256)    262144      ['conv4_block36_preact_relu[0][0]
#                                                                  ']
#
#  conv4_block36_1_bn (BatchNorma  (None, 2, 2, 256)   1024        ['conv4_block36_1_conv[0][0]']
#  lization)
#
#  conv4_block36_1_relu (Activati  (None, 2, 2, 256)   0           ['conv4_block36_1_bn[0][0]']
#  on)
#
#  conv4_block36_2_pad (ZeroPaddi  (None, 4, 4, 256)   0           ['conv4_block36_1_relu[0][0]']
#  ng2D)
#
#  conv4_block36_2_conv (Conv2D)  (None, 1, 1, 256)    589824      ['conv4_block36_2_pad[0][0]']
#
#  conv4_block36_2_bn (BatchNorma  (None, 1, 1, 256)   1024        ['conv4_block36_2_conv[0][0]']
#  lization)
#
#  conv4_block36_2_relu (Activati  (None, 1, 1, 256)   0           ['conv4_block36_2_bn[0][0]']
#  on)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 1, 1, 1024)  0           ['conv4_block35_out[0][0]']
#
#  conv4_block36_3_conv (Conv2D)  (None, 1, 1, 1024)   263168      ['conv4_block36_2_relu[0][0]']
#
#  conv4_block36_out (Add)        (None, 1, 1, 1024)   0           ['max_pooling2d_2[0][0]',
#                                                                   'conv4_block36_3_conv[0][0]']
#
#  conv5_block1_preact_bn (BatchN  (None, 1, 1, 1024)  4096        ['conv4_block36_out[0][0]']
#  ormalization)
#
#  conv5_block1_preact_relu (Acti  (None, 1, 1, 1024)  0           ['conv5_block1_preact_bn[0][0]']
#  vation)
#
#  conv5_block1_1_conv (Conv2D)   (None, 1, 1, 512)    524288      ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#  conv5_block1_1_bn (BatchNormal  (None, 1, 1, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 1, 1, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_pad (ZeroPaddin  (None, 3, 3, 512)   0           ['conv5_block1_1_relu[0][0]']
#  g2D)
#
#  conv5_block1_2_conv (Conv2D)   (None, 1, 1, 512)    2359296     ['conv5_block1_2_pad[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 1, 1, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 1, 1, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 1, 1, 2048)   2099200     ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_3_conv (Conv2D)   (None, 1, 1, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_out (Add)         (None, 1, 1, 2048)   0           ['conv5_block1_0_conv[0][0]',
#                                                                   'conv5_block1_3_conv[0][0]']
#
#  conv5_block2_preact_bn (BatchN  (None, 1, 1, 2048)  8192        ['conv5_block1_out[0][0]']
#  ormalization)
#
#  conv5_block2_preact_relu (Acti  (None, 1, 1, 2048)  0           ['conv5_block2_preact_bn[0][0]']
#  vation)
#
#  conv5_block2_1_conv (Conv2D)   (None, 1, 1, 512)    1048576     ['conv5_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block2_1_bn (BatchNormal  (None, 1, 1, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 1, 1, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_pad (ZeroPaddin  (None, 3, 3, 512)   0           ['conv5_block2_1_relu[0][0]']
#  g2D)
#
#  conv5_block2_2_conv (Conv2D)   (None, 1, 1, 512)    2359296     ['conv5_block2_2_pad[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 1, 1, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 1, 1, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 1, 1, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_out (Add)         (None, 1, 1, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_conv[0][0]']
#
#  conv5_block3_preact_bn (BatchN  (None, 1, 1, 2048)  8192        ['conv5_block2_out[0][0]']
#  ormalization)
#
#  conv5_block3_preact_relu (Acti  (None, 1, 1, 2048)  0           ['conv5_block3_preact_bn[0][0]']
#  vation)
#
#  conv5_block3_1_conv (Conv2D)   (None, 1, 1, 512)    1048576     ['conv5_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block3_1_bn (BatchNormal  (None, 1, 1, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 1, 1, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_pad (ZeroPaddin  (None, 3, 3, 512)   0           ['conv5_block3_1_relu[0][0]']
#  g2D)
#
#  conv5_block3_2_conv (Conv2D)   (None, 1, 1, 512)    2359296     ['conv5_block3_2_pad[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 1, 1, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 1, 1, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 1, 1, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_out (Add)         (None, 1, 1, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_conv[0][0]']
#
#  post_bn (BatchNormalization)   (None, 1, 1, 2048)   8192        ['conv5_block3_out[0][0]']
#
#  post_relu (Activation)         (None, 1, 1, 2048)   0           ['post_bn[0][0]']
#
# ==================================================================================================
# Total params: 58,331,648
# Trainable params: 58,187,904
# Non-trainable params: 143,744
# __________________________________________________________________________________________________

# %%
history = model.fit(train_X, train_y, epochs=10, validation_data=(test_X, test_y))
# Out:
# Epoch 1/10
# 2022-03-17 11:43:22.989918: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8302
# 2022-03-17 11:43:34.322974: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.30GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-03-17 11:43:34.338281: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.41GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-03-17 11:43:36.804610: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.41GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-03-17 11:43:37.077528: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.27GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-03-17 11:43:37.270507: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.27GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-03-17 11:43:37.284111: W tensorflow/core/common_runtime/bfc_allocator.cc:275] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.30GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 194/938 [=====>........................] - ETA: 2:42 - loss: 8.8653 - accuracy: 0.2915
